# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# cd /content
#
# # 1. On supprime l'ancien dossier s'il existe pour éviter les conflits
# rm -rf IA
#
# # 2. On télécharge la version toute fraîche depuis GitHub
# git clone https://github.com/Xenow91/IA.git
#
# echo "Dépôt cloné avec succès !"
# Out:
# Dépôt cloné avec succès !
# Cloning into 'IA'...

# %%
# %%bash
# cd /content/IA
# mkdir -p data
# # On copie les binaires depuis le Drive vers la machine qui a le GPU
# cp /content/drive/MyDrive/IA_Data/train.bin data/
# cp /content/drive/MyDrive/IA_Data/val.bin data/
# echo "Données prêtes pour l'ingestion !"
# Out:
# Données prêtes pour l'ingestion !

# %%
# %%bash
# cd /content/IA
# python train.py
# Out:
# Process is terminated.
